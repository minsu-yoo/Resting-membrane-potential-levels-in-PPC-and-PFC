# %%
import pickle
import pandas as pd
import numpy as np

with open('slice_data.pickle', 'rb') as handle:
    raw_data = pickle.load(handle)

# %%
raw_data.keys()
# Out:
# dict_keys(['ACC_FS', 'PPC_FS', 'ACC_RS', 'PPC_RS'])

# %%
data = raw_data['ACC_FS']

# %% [markdown]
# Get the index of NaN and find the spots to separate the columns

# %%
n_column = data.iloc[0,:].size

# %%
data.iloc[0,1:14]
# Out:
# 20190219 Slice 1 Cell 0   -200.0
# Unnamed: 2                -150.0
# Unnamed: 3                -100.0
# Unnamed: 4                 -50.0
# Unnamed: 5                   0.0
# Unnamed: 6                  50.0
# Unnamed: 7                 100.0
# Unnamed: 8                 150.0
# Unnamed: 9                 200.0
# Unnamed: 10                250.0
# Unnamed: 11                300.0
# Unnamed: 12                350.0
# Unnamed: 13                400.0
# Name: 0, dtype: float64

# %%
data.iloc[0,58]
# Out:
# 400.0

# %%
starting_index = np.arange (1,n_column+1, 15)

# %%
starting_index
# Out:
# array([ 1, 16, 31, 46])

# %%
cell_list = []

# %%
for i in starting_index:
    cell_data = data.iloc[:,i:i+13]
    cell_list.append(cell_data)

# %%
len(cell_list)
# Out:
# 4

# %%
cell_list[0]
# Out:
#        20190219 Slice 1 Cell 0  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0                    -200.0000   -150.0000   -100.0000    -50.0000
# 1                     -75.2563    -74.8901    -75.4089    -74.9817
# 2                     -75.2869    -74.8291    -75.5310    -74.9512
# 3                     -75.2869    -74.8596    -75.4395    -74.9512
# 4                     -75.2563    -74.8291    -75.4700    -75.0122
# ...                        ...         ...         ...         ...
# 10996                 -74.8596    -75.4395    -74.9207    -75.3784
# 10997                 -74.8596    -75.4395    -74.9512    -75.3479
# 10998                 -74.8291    -75.4700    -74.8901    -75.3479
# 10999                 -74.8596    -75.4089    -74.9512    -75.4089
# 11000                 -74.9207    -75.5005    -74.9817    -75.3174
#
#        Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0          0.0000     50.0000    100.0000    150.0000    200.0000
# ...

# %%
a
# Out:
# array([ 1, 16, 31, 46])

# %%
range(3, 20, 2)

# %%
i = 1

[i:i+13]

j = i + 13 + 2

# %% [markdown]
# [i:i+13]
#
# [just_before+2:i:13]

# %%
data_no_time = data.iloc[1:,:]

# %%
clamp_levels = data.iloc[0, :]

# %%
clamp_levels[1:]
# Out:
# 20190219 Slice 1 Cell 0   -200.0
# Unnamed: 2                -150.0
# Unnamed: 3                -100.0
# Unnamed: 4                 -50.0
# Unnamed: 5                   0.0
# Unnamed: 6                  50.0
# Unnamed: 7                 100.0
# Unnamed: 8                 150.0
# Unnamed: 9                 200.0
# Unnamed: 10                250.0
# Unnamed: 11                300.0
# Unnamed: 12                350.0
# Unnamed: 13                400.0
# Unnamed: 14                  NaN
# Unnamed: 15                  NaN
# 20180620 Slice 1 Cell 0   -200.0
# Unnamed: 17               -150.0
# Unnamed: 18               -100.0
# Unnamed: 19                -50.0
# Unnamed: 20                  0.0
# Unnamed: 21                 50.0
# Unnamed: 22                100.0
# Unnamed: 23                150.0
# Unnamed: 24                200.0
# Unnamed: 25                250.0
# Unnamed: 26                300.0
# Unnamed: 27                350.0
# Unnamed: 28                400.0
# ...

# %%
clamp_levels_string = pd.Series(clamp_levels[1:], dtype="string")

# %%
data_no_time
# Out:
#         Unnamed: 0  20190219 Slice 1 Cell 0  Unnamed: 2  Unnamed: 3  \
# 1         0.000000                 -75.2563    -74.8901    -75.4089
# 2         0.100000                 -75.2869    -74.8291    -75.5310
# 3         0.200000                 -75.2869    -74.8596    -75.4395
# 4         0.300000                 -75.2563    -74.8291    -75.4700
# 5         0.400000                 -75.2869    -74.8596    -75.4395
# ...            ...                      ...         ...         ...
# 10996  1099.500000                 -74.8596    -75.4395    -74.9207
# 10997  1099.599976                 -74.8596    -75.4395    -74.9512
# 10998  1099.699951                 -74.8291    -75.4700    -74.8901
# 10999  1099.800049                 -74.8596    -75.4089    -74.9512
# 11000  1099.900024                 -74.9207    -75.5005    -74.9817
#
#        Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# ...

# %%
data_no_time.columns = clamp_levels_string
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\Public\Documents\ESTsoft\CreatorTemp/ipykernel_10520/2595185499.py in <module>
# ----> 1 data_no_time.columns = clamp_levels_string
#
# c:\Users\KBRI\anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5498         try:
#    5499             object.__getattribute__(self, name)
# -> 5500             return object.__setattr__(self, name, value)
#    5501         except AttributeError:
#    5502             pass
#
# c:\Users\KBRI\anaconda3\lib\site-packages\pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# c:\Users\KBRI\anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     764     def _set_axis(self, axis: int, labels: Index) -> None:
#     765         labels = ensure_index(labels)
# ...

# %%
clamp_levels_string.size
# Out:
# 58

# %%
data_no_time.iloc[0,:].size
# Out:
# 59

# %%
data_no_time.iloc[0,:]
# Out:
# Unnamed: 0                  0.0000
# 20190219 Slice 1 Cell 0   -75.2563
# Unnamed: 2                -74.8901
# Unnamed: 3                -75.4089
# Unnamed: 4                -74.9817
# Unnamed: 5                -75.4395
# Unnamed: 6                -75.3174
# Unnamed: 7                -75.1953
# Unnamed: 8                -75.8057
# Unnamed: 9                -76.4465
# Unnamed: 10               -78.3386
# Unnamed: 11               -79.9561
# Unnamed: 12               -80.8716
# Unnamed: 13               -82.0312
# Unnamed: 14                    NaN
# Unnamed: 15                 0.0000
# 20180620 Slice 1 Cell 0   -75.9583
# Unnamed: 17               -75.9583
# Unnamed: 18               -75.9888
# Unnamed: 19               -75.9888
# Unnamed: 20               -76.1414
# Unnamed: 21               -75.9888
# Unnamed: 22               -75.8667
# Unnamed: 23               -76.3550
# Unnamed: 24               -76.6602
# Unnamed: 25               -77.7283
# Unnamed: 26               -78.8574
# ...

# %%
clamp_levels_string
# Out:
# 20190219 Slice 1 Cell 0    -200.0
# Unnamed: 2                 -150.0
# Unnamed: 3                 -100.0
# Unnamed: 4                  -50.0
# Unnamed: 5                    0.0
# Unnamed: 6                   50.0
# Unnamed: 7                  100.0
# Unnamed: 8                  150.0
# Unnamed: 9                  200.0
# Unnamed: 10                 250.0
# Unnamed: 11                 300.0
# Unnamed: 12                 350.0
# Unnamed: 13                 400.0
# Unnamed: 14                  <NA>
# Unnamed: 15                  <NA>
# 20180620 Slice 1 Cell 0    -200.0
# Unnamed: 17                -150.0
# Unnamed: 18                -100.0
# Unnamed: 19                 -50.0
# Unnamed: 20                   0.0
# Unnamed: 21                  50.0
# Unnamed: 22                 100.0
# Unnamed: 23                 150.0
# Unnamed: 24                 200.0
# Unnamed: 25                 250.0
# Unnamed: 26                 300.0
# Unnamed: 27                 350.0
# ...

# %%
data
# Out:
# 0              NaN   -200.0   -150.0   -100.0    -50.0      0.0     50.0  \
# 1         0.000000 -75.2563 -74.8901 -75.4089 -74.9817 -75.4395 -75.3174
# 2         0.100000 -75.2869 -74.8291 -75.5310 -74.9512 -75.3784 -75.3784
# 3         0.200000 -75.2869 -74.8596 -75.4395 -74.9512 -75.4395 -75.2869
# 4         0.300000 -75.2563 -74.8291 -75.4700 -75.0122 -75.4395 -75.3479
# 5         0.400000 -75.2869 -74.8596 -75.4395 -74.9207 -75.4395 -75.3174
# ...            ...      ...      ...      ...      ...      ...      ...
# 10996  1099.500000 -74.8596 -75.4395 -74.9207 -75.3784 -75.3784 -75.1038
# 10997  1099.599976 -74.8596 -75.4395 -74.9512 -75.3479 -75.3479 -75.1953
# 10998  1099.699951 -74.8291 -75.4700 -74.8901 -75.3479 -75.3174 -75.1038
# 10999  1099.800049 -74.8596 -75.4089 -74.9512 -75.4089 -75.3174 -75.1648
# 11000  1099.900024 -74.9207 -75.5005 -74.9817 -75.3174 -75.3479 -75.0732
#
# 0        100.0    150.0    200.0  ...    -50.0      0.0     50.0    100.0  \
# ...

# %%
data.iloc[:,1]
# Out:
# 0       -200.0000
# 1        -75.2563
# 2        -75.2869
# 3        -75.2869
# 4        -75.2563
#            ...
# 10996    -74.8596
# 10997    -74.8596
# 10998    -74.8291
# 10999    -74.8596
# 11000    -74.9207
# Name: 20190219 Slice 1 Cell 0, Length: 11001, dtype: float64

# %%
clamp_levels = data.iloc[0, :]

# %%
data.iloc[0,:]
# Out:
# 0
# NaN        0.0000
# -200.0   -75.2563
# -150.0   -74.8901
# -100.0   -75.4089
# -50.0    -74.9817
# 0.0      -75.4395
# 50.0     -75.3174
# 100.0    -75.1953
# 150.0    -75.8057
# 200.0    -76.4465
# 250.0    -78.3386
# 300.0    -79.9561
# 350.0    -80.8716
# 400.0    -82.0312
# NaN           NaN
# NaN        0.0000
# -200.0   -75.9583
# -150.0   -75.9583
# -100.0   -75.9888
# -50.0    -75.9888
# 0.0      -76.1414
# 50.0     -75.9888
# 100.0    -75.8667
# 150.0    -76.3550
# 200.0    -76.6602
# 250.0    -77.7283
# 300.0    -78.8574
# 350.0    -79.6509
# 400.0    -80.4749
# NaN           NaN
# NaN        0.0000
# -200.0   -70.9229
# -150.0   -71.1670
# -100.0   -70.1294
# -50.0    -70.5872
# 0.0      -71.5332
# 50.0     -70.8313
# 100.0    -72.1741
# 150.0    -71.8079
# 200.0    -73.3643
# 250.0    -74.6765
# 300.0    -76.3855
# 350.0    -76.9043
# 400.0    -75.5005
# NaN           NaN
# NaN        0.0000
# -200.0   -73.3337
# -150.0   -73.7305
# -100.0   -73.7610
# ...

# %%
clamp_levels_string = pd.Series(clamp_levels, dtype="string")

# %%
data.columns = clamp_levels_string

# %%
data.iloc[:,0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\KBRI\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# c:\Users\KBRI\anaconda3\lib\site-packages\IPython\lib\pretty.py in pretty(self, obj)
#     392                         if cls is not object \
#     393                                 and callable(cls.__dict__.get('__repr__')):
# --> 394                             return _repr_pprint(obj, self, cycle)
#     395
#     396             return _default_pprint(obj, self, cycle)
#
# c:\Users\KBRI\anaconda3\lib\site-packages\IPython\lib\pretty.py in _repr_pprint(obj, p, cycle)
# ...

# %%
data['100.0']
# Out:
# c:\Users\KBRI\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3361: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   return self._engine.get_loc(casted_key)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\Public\Documents\ESTsoft\CreatorTemp/ipykernel_18444/3273196808.py in <module>
# ----> 1 data['100.0']
#
# c:\Users\KBRI\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# c:\Users\KBRI\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
# ...

# %%
data['-200.0']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\Public\Documents\ESTsoft\CreatorTemp/ipykernel_18444/1725658921.py in <module>
# ----> 1 data['-200.0']
#
# c:\Users\KBRI\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# c:\Users\KBRI\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3359             casted_key = self._maybe_cast_indexer(key)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# ...

# %%
test = data

# %%
test.drop([0], axis=0, inplace=True)

# %%
rmp_time  = data.iloc[:, 0]

# %%
rmp_time[1:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\KBRI\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# c:\Users\KBRI\anaconda3\lib\site-packages\IPython\lib\pretty.py in pretty(self, obj)
#     392                         if cls is not object \
#     393                                 and callable(cls.__dict__.get('__repr__')):
# --> 394                             return _repr_pprint(obj, self, cycle)
#     395
#     396             return _default_pprint(obj, self, cycle)
#
# c:\Users\KBRI\anaconda3\lib\site-packages\IPython\lib\pretty.py in _repr_pprint(obj, p, cycle)
# ...

# %%
test
# Out:
# 0              NaN   -200.0   -150.0   -100.0    -50.0      0.0     50.0  \
# 1         0.000000 -75.2563 -74.8901 -75.4089 -74.9817 -75.4395 -75.3174
# 2         0.100000 -75.2869 -74.8291 -75.5310 -74.9512 -75.3784 -75.3784
# 3         0.200000 -75.2869 -74.8596 -75.4395 -74.9512 -75.4395 -75.2869
# 4         0.300000 -75.2563 -74.8291 -75.4700 -75.0122 -75.4395 -75.3479
# 5         0.400000 -75.2869 -74.8596 -75.4395 -74.9207 -75.4395 -75.3174
# ...            ...      ...      ...      ...      ...      ...      ...
# 10996  1099.500000 -74.8596 -75.4395 -74.9207 -75.3784 -75.3784 -75.1038
# 10997  1099.599976 -74.8596 -75.4395 -74.9512 -75.3479 -75.3479 -75.1953
# 10998  1099.699951 -74.8291 -75.4700 -74.8901 -75.3479 -75.3174 -75.1038
# 10999  1099.800049 -74.8596 -75.4089 -74.9512 -75.4089 -75.3174 -75.1648
# 11000  1099.900024 -74.9207 -75.5005 -74.9817 -75.3174 -75.3479 -75.0732
#
# 0        100.0    150.0    200.0  ...    -50.0      0.0     50.0    100.0  \
# ...

# %%
test.iloc[:, 1]
# Out:
# 1       -75.2563
# 2       -75.2869
# 3       -75.2869
# 4       -75.2563
# 5       -75.2869
#           ...
# 10996   -74.8596
# 10997   -74.8596
# 10998   -74.8291
# 10999   -74.8596
# 11000   -74.9207
# Name: -200.0, Length: 11000, dtype: float64

# %%
rmp_time  = test.iloc[1:, 0]

# %%
rmp_time
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\KBRI\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# c:\Users\KBRI\anaconda3\lib\site-packages\IPython\lib\pretty.py in pretty(self, obj)
#     392                         if cls is not object \
#     393                                 and callable(cls.__dict__.get('__repr__')):
# --> 394                             return _repr_pprint(obj, self, cycle)
#     395
#     396             return _default_pprint(obj, self, cycle)
#
# c:\Users\KBRI\anaconda3\lib\site-packages\IPython\lib\pretty.py in _repr_pprint(obj, p, cycle)
# ...

# %%
test.drop()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\Public\Documents\ESTsoft\CreatorTemp/ipykernel_21756/1497134851.py in <module>
# ----> 1 test.drop()
#
# c:\Users\KBRI\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\Users\KBRI\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# c:\Users\KBRI\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
clamp_levels
# Out:
# Unnamed: 0                   NaN
# 20190219 Slice 1 Cell 0   -200.0
# Unnamed: 2                -150.0
# Unnamed: 3                -100.0
# Unnamed: 4                 -50.0
# Unnamed: 5                   0.0
# Unnamed: 6                  50.0
# Unnamed: 7                 100.0
# Unnamed: 8                 150.0
# Unnamed: 9                 200.0
# Unnamed: 10                250.0
# Unnamed: 11                300.0
# Unnamed: 12                350.0
# Unnamed: 13                400.0
# Unnamed: 14                  NaN
# Unnamed: 15                  NaN
# 20180620 Slice 1 Cell 0   -200.0
# Unnamed: 17               -150.0
# Unnamed: 18               -100.0
# Unnamed: 19                -50.0
# Unnamed: 20                  0.0
# Unnamed: 21                 50.0
# Unnamed: 22                100.0
# Unnamed: 23                150.0
# Unnamed: 24                200.0
# Unnamed: 25                250.0
# Unnamed: 26                300.0
# Unnamed: 27                350.0
# ...

# %%
data.head()
# Out:
#    Unnamed: 0  20190219 Slice 1 Cell 0  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0         NaN                -200.0000   -150.0000   -100.0000    -50.0000
# 1         0.0                 -75.2563    -74.8901    -75.4089    -74.9817
# 2         0.1                 -75.2869    -74.8291    -75.5310    -74.9512
# 3         0.2                 -75.2869    -74.8596    -75.4395    -74.9512
# 4         0.3                 -75.2563    -74.8291    -75.4700    -75.0122
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 0      0.0000     50.0000    100.0000    150.0000    200.0000  ...
# 1    -75.4395    -75.3174    -75.1953    -75.8057    -76.4465  ...
# 2    -75.3784    -75.3784    -75.1038    -75.8362    -76.3855  ...
# 3    -75.4395    -75.2869    -75.1953    -75.7751    -76.3855  ...
# 4    -75.4395    -75.3479    -75.1343    -75.8057    -76.5076  ...
#
#    Unnamed: 49  Unnamed: 50  Unnamed: 51  Unnamed: 52  Unnamed: 53  \
# ...

# %%
data
# Out:
#         Unnamed: 0  20190219 Slice 1 Cell 0  Unnamed: 2  Unnamed: 3  \
# 0              NaN                -200.0000   -150.0000   -100.0000
# 1         0.000000                 -75.2563    -74.8901    -75.4089
# 2         0.100000                 -75.2869    -74.8291    -75.5310
# 3         0.200000                 -75.2869    -74.8596    -75.4395
# 4         0.300000                 -75.2563    -74.8291    -75.4700
# ...            ...                      ...         ...         ...
# 10996  1099.500000                 -74.8596    -75.4395    -74.9207
# 10997  1099.599976                 -74.8596    -75.4395    -74.9512
# 10998  1099.699951                 -74.8291    -75.4700    -74.8901
# 10999  1099.800049                 -74.8596    -75.4089    -74.9512
# 11000  1099.900024                 -74.9207    -75.5005    -74.9817
#
#        Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# ...

# %%
rmp_time  = data.iloc[:, 0]

# %%
rmp_time
# Out:
# 0                NaN
# 1           0.000000
# 2           0.100000
# 3           0.200000
# 4           0.300000
#             ...
# 10996    1099.500000
# 10997    1099.599976
# 10998    1099.699951
# 10999    1099.800049
# 11000    1099.900024
# Name: Unnamed: 0, Length: 11001, dtype: float64

# %%
a

# %%
clamp_levels
# Out:
# 20190219 Slice 1 Cell 0   -200.0
# Unnamed: 2                -150.0
# Unnamed: 3                -100.0
# Unnamed: 4                 -50.0
# Unnamed: 5                   0.0
# Unnamed: 6                  50.0
# Unnamed: 7                 100.0
# Unnamed: 8                 150.0
# Unnamed: 9                 200.0
# Unnamed: 10                250.0
# Unnamed: 11                300.0
# Unnamed: 12                350.0
# Unnamed: 13                400.0
# Name: 0, dtype: float64

# %%
import pandas as pd

# %%
clamp_levels_string = pd.Series(clamp_levels, dtype="string")

# %%
clamp_levels_string
# Out:
# 20190219 Slice 1 Cell 0    -200.0
# Unnamed: 2                 -150.0
# Unnamed: 3                 -100.0
# Unnamed: 4                  -50.0
# Unnamed: 5                    0.0
# Unnamed: 6                   50.0
# Unnamed: 7                  100.0
# Unnamed: 8                  150.0
# Unnamed: 9                  200.0
# Unnamed: 10                 250.0
# Unnamed: 11                 300.0
# Unnamed: 12                 350.0
# Unnamed: 13                 400.0
# Name: 0, dtype: string

# %%
first_cell = data.iloc[1:, 1:14]

# %%
first_cell
# Out:
#        20190219 Slice 1 Cell 0  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 1                     -75.2563    -74.8901    -75.4089    -74.9817
# 2                     -75.2869    -74.8291    -75.5310    -74.9512
# 3                     -75.2869    -74.8596    -75.4395    -74.9512
# 4                     -75.2563    -74.8291    -75.4700    -75.0122
# 5                     -75.2869    -74.8596    -75.4395    -74.9207
# ...                        ...         ...         ...         ...
# 10996                 -74.8596    -75.4395    -74.9207    -75.3784
# 10997                 -74.8596    -75.4395    -74.9512    -75.3479
# 10998                 -74.8291    -75.4700    -74.8901    -75.3479
# 10999                 -74.8596    -75.4089    -74.9512    -75.4089
# 11000                 -74.9207    -75.5005    -74.9817    -75.3174
#
#        Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 1        -75.4395    -75.3174    -75.1953    -75.8057    -76.4465
# ...

# %%
first_cell.columns = clamp_levels_string

# %%
first_cell
# Out:
# 0       -200.0   -150.0   -100.0    -50.0      0.0     50.0    100.0    150.0  \
# 1     -75.2563 -74.8901 -75.4089 -74.9817 -75.4395 -75.3174 -75.1953 -75.8057
# 2     -75.2869 -74.8291 -75.5310 -74.9512 -75.3784 -75.3784 -75.1038 -75.8362
# 3     -75.2869 -74.8596 -75.4395 -74.9512 -75.4395 -75.2869 -75.1953 -75.7751
# 4     -75.2563 -74.8291 -75.4700 -75.0122 -75.4395 -75.3479 -75.1343 -75.8057
# 5     -75.2869 -74.8596 -75.4395 -74.9207 -75.4395 -75.3174 -75.2258 -75.7446
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 10996 -74.8596 -75.4395 -74.9207 -75.3784 -75.3784 -75.1038 -75.7141 -76.3855
# 10997 -74.8596 -75.4395 -74.9512 -75.3479 -75.3479 -75.1953 -75.8362 -76.3550
# 10998 -74.8291 -75.4700 -74.8901 -75.3479 -75.3174 -75.1038 -75.7751 -76.3855
# 10999 -74.8596 -75.4089 -74.9512 -75.4089 -75.3174 -75.1648 -75.8362 -76.4160
# 11000 -74.9207 -75.5005 -74.9817 -75.3174 -75.3479 -75.0732 -75.7446 -76.4160
#
# ...

# %%
data
# Out:
#         Unnamed: 0  20190219 Slice 1 Cell 0  Unnamed: 2  Unnamed: 3  \
# 0              NaN                -200.0000   -150.0000   -100.0000
# 1         0.000000                 -75.2563    -74.8901    -75.4089
# 2         0.100000                 -75.2869    -74.8291    -75.5310
# 3         0.200000                 -75.2869    -74.8596    -75.4395
# 4         0.300000                 -75.2563    -74.8291    -75.4700
# ...            ...                      ...         ...         ...
# 10996  1099.500000                 -74.8596    -75.4395    -74.9207
# 10997  1099.599976                 -74.8596    -75.4395    -74.9512
# 10998  1099.699951                 -74.8291    -75.4700    -74.8901
# 10999  1099.800049                 -74.8596    -75.4089    -74.9512
# 11000  1099.900024                 -74.9207    -75.5005    -74.9817
#
#        Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# ...
