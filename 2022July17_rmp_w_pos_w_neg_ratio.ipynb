# %% [markdown]
# # $ w_- = 1 - \frac{f(w_+-1)}{1-f}$

# %%
# Imports
import matplotlib.pyplot as plt
import numpy as np
import scipy.optimize as opt  # root-finding algorithm

# %%
# @title Figure Settings
import ipywidgets as widgets       # interactive display
# %config InlineBackend.figure_format = 'retina'
plt.style.use("https://raw.githubusercontent.com/NeuromatchAcademy/course-content/master/nma.mplstyle")

# %%
def w_neg(w_pos):
    w_neg = 1-(0.15*(w_pos -1)/(1-0.15))
    return w_neg

# %%
w_neg(1.7)
# Out:
# 0.8764705882352941

# %%
# @title

# @markdown Make sure you execute this cell to enable the widget!


def plot_nullcline_diffwEE(wEE):
  """
    plot nullclines for different values of wEE
  ""

_ = widgets.interact(plot_nullcline_diffwEE, wEE=(6., 10., .01))
# Out:
#   Input In [8]
#     _ = widgets.interact(plot_nullcline_diffwEE, wEE=(6., 10., .01))
#
# ^
# SyntaxError: EOF while scanning triple-quoted string literal

# %%
w_neg_list = w_neg(w_pos)

# %%
w_pos = np.linspace(1, 10, 100)

plt.plot(w_pos, w_neg_list)
plt.show()

# %%
def plot_w_neg(w_pos):
