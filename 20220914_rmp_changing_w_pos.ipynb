# %%
import brian2 as b2
from neurodynex3.tools import plot_tools
from neurodynex3.competing_populations import decision_making
import matplotlib.pyplot as plt


results = decision_making.sim_decision_making_network(t_stimulus_start= 50. * b2.ms,
                                                      coherence_level=-0.6, max_sim_time=1000. * b2.ms)
plot_tools.plot_network_activity(results["rate_monitor_A"], results["spike_monitor_A"],
                                 results["voltage_monitor_A"], t_min=0. * b2.ms, avg_window_width=2. * b2.ms,
                                 sup_title="Left")
plot_tools.plot_network_activity(results["rate_monitor_B"], results["spike_monitor_B"],
                                 results["voltage_monitor_B"], t_min=0. * b2.ms, avg_window_width=2. * b2.ms,
                                 sup_title="Right")
plt.show()

# %%
import wang

stim_start = 100. * b2.ms
stim_duration = 700 * b2.ms

pop_rate_list = []


results = wang.sim_decision_making_network(N_Excit=341, N_Inhib=85, weight_scaling_factor=6.0,
                                        t_stimulus_start=stim_start, t_stimulus_duration=stim_duration,
                                        coherence_level=+0.90, w_pos=1.7, mu0_mean_stimulus_Hz=500 * b2.Hz,
                                        max_sim_time=800. * b2.ms)




plot_tools.plot_network_activity(results["rate_monitor_A"], results["spike_monitor_A"],
                                 results["voltage_monitor_A"], t_min=0. * b2.ms, avg_window_width=2. * b2.ms,
                                 sup_title="Left")
plot_tools.plot_network_activity(results["rate_monitor_B"], results["spike_monitor_B"],
                                 results["voltage_monitor_B"], t_min=0. * b2.ms, avg_window_width=2. * b2.ms,
                                 sup_title="Right")
plt.show()
# Out:
# simulating 426 neurons. Start: Wed Sep 14 15:18:18 2022
# sim end: Wed Sep 14 15:19:14 2022

# %%
import numpy as np

# %%
def plot_rate(pop_rate):
    rate_a = pop_rate['pop_rate_a']
    rate_b = pop_rate['pop_rate_b']
    time = pop_rate['time']
    plt.rcParams['font.size'] = 18

    
    
    plt.plot(time, rate_a,  linewidth= 2.5)
    plt.plot(time, rate_b, linewidth= 2.5)
    plt.ylabel('Firing rate (Spikes/s)')
    plt.xlabel('time (ms)')
    plt.legend(['Population A', 'Population B'])
    plt.show()

# %%
def pop_rate_to_dict(results):

    pop_rate_a = results["rate_monitor_A"]
    pop_rate_b = results["rate_monitor_B"]
    
    # pop_rate_a is a 

    smooth_pop_rate_a = pop_rate_a.smooth_rate(window="flat",width = 20.1*b2.ms )
    smooth_pop_rate_b = pop_rate_b.smooth_rate(window="flat",width = 20.1*b2.ms )

    np_rate_a = np.array(smooth_pop_rate_a)
    np_rate_b = np.array(smooth_pop_rate_b)



    time = pop_rate_a.t/b2.ms
    pop_rate_results = {}

    pop_rate_results['time'] =  time
    pop_rate_results['pop_rate_a'] =  np_rate_a
    pop_rate_results['pop_rate_b'] =  np_rate_b
    pop_rate_results['stim_info'] = '100ms to 800ms for 700 ms'
    
    return pop_rate_results

# %%
results_pop = pop_rate_to_dict(results)

# %%
plot_rate(results_pop)

# %%
results = wang.sim_decision_making_network(N_Excit=341, N_Inhib=85, weight_scaling_factor=6.0,
                                        t_stimulus_start=stim_start, t_stimulus_duration=stim_duration,
                                        coherence_level=+0.90, w_pos=1.2, mu0_mean_stimulus_Hz=500 * b2.Hz,
                                        max_sim_time=800. * b2.ms)
# Out:
# simulating 426 neurons. Start: Wed Sep 14 15:30:31 2022
# sim end: Wed Sep 14 15:31:11 2022

# %%
results_pop = pop_rate_to_dict(results)
plot_rate(results_pop)

print('The weight is 1.2')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Untitled-1.ipynb 셀 10 in <cell line: 3>()
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X12sdW50aXRsZWQ%3D?line=0'>1</a> results_pop = pop_rate_to_dict(results)
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X12sdW50aXRsZWQ%3D?line=1'>2</a> plot_rate(results_pop)
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X12sdW50aXRsZWQ%3D?line=2'>3</a> print('The weight is 1.2')
#
# TypeError: 'str' object is not callable

# %%
results = wang.sim_decision_making_network(N_Excit=341, N_Inhib=85, weight_scaling_factor=6.0,
                                        t_stimulus_start=stim_start, t_stimulus_duration=stim_duration,
                                        coherence_level=+0.90, w_pos=1.8, mu0_mean_stimulus_Hz=500 * b2.Hz,
                                        max_sim_time=800. * b2.ms)
# Out:
# simulating 426 neurons. Start: Wed Sep 14 15:33:39 2022
# sim end: Wed Sep 14 15:36:50 2022

# %% [markdown]
# w_pos = 1.8

# %%
results_pop = pop_rate_to_dict(results)
plot_rate(results_pop)

# %% [markdown]
# w=1.9

# %%
results = wang.sim_decision_making_network(N_Excit=341, N_Inhib=85, weight_scaling_factor=6.0,
                                        t_stimulus_start=stim_start, t_stimulus_duration=stim_duration,
                                        coherence_level=+0.90, w_pos=1.9, mu0_mean_stimulus_Hz=500 * b2.Hz,
                                        max_sim_time=800. * b2.ms)
# Out:
# simulating 426 neurons. Start: Wed Sep 14 15:37:51 2022
# sim end: Wed Sep 14 15:38:31 2022

# %%
results_pop = pop_rate_to_dict(results)
plot_rate(results_pop)

# %%
results = wang.sim_decision_making_network(N_Excit=341, N_Inhib=85, weight_scaling_factor=6.0,
                                        t_stimulus_start=stim_start, t_stimulus_duration=stim_duration,
                                        coherence_level=+0.90, w_pos=2.0, mu0_mean_stimulus_Hz=500 * b2.Hz,
                                        max_sim_time=800. * b2.ms)
# Out:
# simulating 426 neurons. Start: Wed Sep 14 15:38:54 2022
# sim end: Wed Sep 14 15:39:35 2022

# %% [markdown]
# w_pos = 2.0

# %%
results_pop = pop_rate_to_dict(results)
plot_rate(results_pop)

# %% [markdown]
# w_pos = 2.1

# %%
results = wang.sim_decision_making_network(N_Excit=341, N_Inhib=85, weight_scaling_factor=6.0,
                                        t_stimulus_start=stim_start, t_stimulus_duration=stim_duration,
                                        coherence_level=+0.90, w_pos=2.1, mu0_mean_stimulus_Hz=500 * b2.Hz,
                                        max_sim_time=800. * b2.ms)
# Out:
# simulating 426 neurons. Start: Wed Sep 14 16:11:07 2022
# sim end: Wed Sep 14 16:11:47 2022

# %%
results_pop = pop_rate_to_dict(results)
plot_rate(results_pop)

# %% [markdown]
# w_pos = 2.2

# %%
results = wang.sim_decision_making_network(N_Excit=341, N_Inhib=85, weight_scaling_factor=6.0,
                                        t_stimulus_start=stim_start, t_stimulus_duration=stim_duration,
                                        coherence_level=+0.90, w_pos=2.2, mu0_mean_stimulus_Hz=500 * b2.Hz,
                                        max_sim_time=800. * b2.ms)
# Out:
# simulating 426 neurons. Start: Wed Sep 14 16:12:27 2022
# sim end: Wed Sep 14 16:13:08 2022

# %%
results_pop = pop_rate_to_dict(results)
plot_rate(results_pop)

# %% [markdown]
# w_pos = 2.3

# %%
results = wang.sim_decision_making_network(N_Excit=341, N_Inhib=85, weight_scaling_factor=6.0,
                                        t_stimulus_start=stim_start, t_stimulus_duration=stim_duration,
                                        coherence_level=+0.90, w_pos=2.3, mu0_mean_stimulus_Hz=500 * b2.Hz,
                                        max_sim_time=800. * b2.ms)
# Out:
# simulating 426 neurons. Start: Wed Sep 14 16:13:49 2022
# sim end: Wed Sep 14 16:14:30 2022

# %%
results_pop = pop_rate_to_dict(results)
plot_rate(results_pop)

# %%
w_increase = np.arange(2.4, 3.0, 0.1)

# %%
plt.style.use("./nma.mplstyle")

# %%
plot_tools.plot_network_activity(results["rate_monitor_A"], results["spike_monitor_A"],
                                 results["voltage_monitor_A"], t_min=0. * b2.ms, avg_window_width=2. * b2.ms,
                                 sup_title="Left")
plot_tools.plot_network_activity(results["rate_monitor_B"], results["spike_monitor_B"],
                                 results["voltage_monitor_B"], t_min=0. * b2.ms, avg_window_width=2. * b2.ms,
                                 sup_title="Right")
plt.show()

# %% [markdown]
# w_pos = 2.4

# %%
results = wang.sim_decision_making_network(N_Excit=341, N_Inhib=85, weight_scaling_factor=6.0,
                                        t_stimulus_start=stim_start, t_stimulus_duration=stim_duration,
                                        coherence_level=+0.90, w_pos=2.4, mu0_mean_stimulus_Hz=500 * b2.Hz,
                                        max_sim_time=800. * b2.ms)
# Out:
# simulating 426 neurons. Start: Wed Sep 14 16:24:51 2022
# sim end: Wed Sep 14 16:25:32 2022

# %%
plt.style.use("./nma.mplstyle")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\msyoo7\ppc_modeling\rmp-master\20220914_rmp_changing_w_pos.ipynb 셀 36 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/msyoo7/ppc_modeling/rmp-master/20220914_rmp_changing_w_pos.ipynb#X52sZmlsZQ%3D%3D?line=0'>1</a> plt.style.use("./nma.mplstyle")
#
# NameError: name 'plt' is not defined

# %%
results_pop = pop_rate_to_dict(results)
plot_rate(results_pop)
