# %%
file_name_list = ['w_pos_1p5_pop_rate_0919_17_50',
                  'w_pos_1p6_pop_rate_0921_14_01',
                  'w_pos_1p7_pop_rate_0921_15_02',
                  'w_pos_1p8_pop_rate_0921_14_13',
                  'w_pos_1p9_pop_rate_0921_15_14',
                  'w_pos_2p0_pop_rate_0921_15_26',
                  'w_pos_2p1_pop_rate_0921_15_39',
                  'w_pos_2p2_pop_rate_0921_15_51']

# %%
import rt_plot as rt

# %%
rt_for_boxplot_list = []

# %%
for i in range(len(file_name_list)):
    rt_for_boxplot_list.append(rt.rt_plot(file_name_list[i] +'.pkl'))

# %%
rt_for_boxplot_list
# Out:
# [array([472.7, 525.4, 153. , 302.2, 165.2, 297.5, 586. , 166.3, 184.3]),
#  array([ 73.1, 286.5, 381.2, 292.9, 335.4, 156.2, 164.2, 177.3, 317.9,
#         302.1]),
#  array([207.9, 130.1, 164.5, 178. , 138.2,  98.6, 123.5, 133.6, 103.8,
#         206.3]),
#  array([198.9, 143.1, 107.6, 115.3, 142.4, 213.4, 189.1, 175. , 157.7,
#         148.2]),
#  array([ 95.8,  78.8, 177.5, 101.1,  84.2, 123.7, 132.8, 130. , 109.1,
#         171.3]),
#  array([145.8,  39.9, 180.7,  94.5,  90.2,  72.6, 128.5, 176.6, 102.8,
#          91. ]),
#  array([ 37.5,  85.4, 202.3,  80.2, 210.1, 157.3, 156.7,  30. ,  65.1,
#         119.1]),
#  array([132.3, 138.6,  29.5,  57.1,  65.5,  95.8, 231.5, 129.3, 139.8,
#          65.1])]

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use("./nma.mplstyle")

# %%
plt.boxplot(rt_for_boxplot_list)
plt.xticks([1,2,3,4,5,6,7,8], w_pos_tick)
plt.xlabel('w_pos')
plt.ylabel('reaction time (ms)')


plt.show()

# %%
w_pos_tick = ['1.5', '1.6', '1.7', '1.8', '1.9', '2.0', '2.1', '2.2']
