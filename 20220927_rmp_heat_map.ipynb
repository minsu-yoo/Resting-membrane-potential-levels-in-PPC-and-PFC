# %%
import pickle
import numpy
import matplotlib.pylab as plt
# %config InlineBackend.figure_format = 'retina'
plt.style.use("https://raw.githubusercontent.com/NeuromatchAcademy/course-content/master/nma.mplstyle")
from datetime import datetime

# %%
with open('w_pos_rmp_8_by_8_10times0923_06_36.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
def get_decision_time(pop_rate, threshold=25):
    rate_A = pop_rate['pop_rate_a']
    rate_B = pop_rate['pop_rate_b']
    
    above_thre_A = (pop_rate['pop_rate_a'] > threshold)
    idx_over_threshold_A = numpy.where(above_thre_A==True)


    above_thre_B = (pop_rate['pop_rate_b'] > threshold)
    idx_over_threshold_B = numpy.where(above_thre_B==True)

    # monitor each firing rate at every moment 
    decision_time_A = 0

    decision_time_B = 0

    for i in range(len(above_thre_A)):

        # find the time when the divergen starts happening

        above_thre_A = (rate_A > threshold)
        idx_over_threshold_A = numpy.where(above_thre_A==True)


        above_thre_B = (rate_B > threshold)
        idx_over_threshold_B = numpy.where(above_thre_B==True)



    if len(idx_over_threshold_A[0]) > 0:
        decision_time_A = idx_over_threshold_A[0][0];
        
    else: 
        pass

    if len(idx_over_threshold_B[0]) > 0:
        decision_time_B = idx_over_threshold_B[0][0];

    else: 
        pass
    

    #print(decision_time_A, decision_time_B)
    return decision_time_A, decision_time_B

# %%
def plot_rate(pop_rate):
    rate_a = pop_rate['pop_rate_a']
    rate_b = pop_rate['pop_rate_b']
    time = pop_rate['time']
    plt.rcParams['font.size'] = 18
    
    
    plt.plot(time, rate_a,  linewidth= 2.5)
    plt.plot(time, rate_b, linewidth= 2.5)
    plt.ylabel('Firing rate (Spikes/s)')
    plt.xlabel('time (ms)')
    plt.legend(['Population A', 'Population B'])
    plt.show()

# %%
data = data[keysList[0]]

# %%
len(data)
# Out:
# 10

# %%
decision_times = []
rt = []

for i in range(len(data)):
    
    decision_time = get_decision_time(data[i])
    
    decision_times.append(decision_time)
    rt.append(max(decision_time))

# %%
rt
# Out:
# [4675, 7089, 3174, 3316, 4262, 3221, 4500, 5135, 3981, 4889]

# %%
rt_in_realtime = numpy.array(rt) - 1000
rt_in_realtime = rt_in_realtime/10


mean_rt = rt_in_realtime.mean()

plt.boxplot(rt_in_realtime)
plt.show()

# %%
get_decision_time(data[i])
# Out:
# (4889, 0)

# %%
data[0]
# Out:
# {'time': array([0.0000e+00, 1.0000e-01, 2.0000e-01, ..., 1.1997e+03, 1.1998e+03,
#         1.1999e+03]),
#  'pop_rate_a': array([0.       , 0.       , 0.       , ..., 3.5118525, 3.5118525,
#         3.5118525]),
#  'pop_rate_b': array([0.      , 0.      , 0.      , ..., 2.341235, 2.341235, 2.341235])}

# %%
plot_rate(data[0])

# %%
data
# Out:
# [{'time': array([0.0000e+00, 1.0000e-01, 2.0000e-01, ..., 1.1997e+03, 1.1998e+03,
#          1.1999e+03]),
#   'pop_rate_a': array([0.       , 0.       , 0.       , ..., 3.5118525, 3.5118525,
#          3.5118525]),
#   'pop_rate_b': array([0.      , 0.      , 0.      , ..., 2.341235, 2.341235, 2.341235])},
#  {'time': array([0.0000e+00, 1.0000e-01, 2.0000e-01, ..., 1.1997e+03, 1.1998e+03,
#          1.1999e+03]),
#   'pop_rate_a': array([0.        , 0.        , 0.        , ..., 1.75592625, 1.1706175 ,
#          1.1706175 ]),
#   'pop_rate_b': array([0.        , 0.        , 0.        , ..., 1.75592625, 1.75592625,
#          1.75592625])},
#  {'time': array([0.0000e+00, 1.0000e-01, 2.0000e-01, ..., 1.1997e+03, 1.1998e+03,
#          1.1999e+03]),
#   'pop_rate_a': array([0.      , 0.      , 0.      , ..., 2.341235, 2.341235, 2.341235]),
#   'pop_rate_b': array([0.58530875, 0.58530875, 1.1706175 , ..., 2.341235  , 2.341235  ,
#          2.341235  ])},
#  {'time': array([0.0000e+00, 1.0000e-01, 2.0000e-01, ..., 1.1997e+03, 1.1998e+03,
#          1.1999e+03]),
#   'pop_rate_a': array([1.1706175, 1.1706175, 1.1706175, ..., 2.341235 , 2.341235 ,
#          2.341235 ]),
#   'pop_rate_b': array([0.58530875, 0.58530875, 0.58530875, ..., 2.92654375, 2.341235  ,
#          2.341235  ])},
#  {'time': array([0.0000e+00, 1.0000e-01, 2.0000e-01, ..., 1.1997e+03, 1.1998e+03,
#          1.1999e+03]),
#   'pop_rate_a': array([0.      , 0.      , 0.      , ..., 2.341235, 2.341235, 2.341235]),
#   'pop_rate_b': array([0.       , 0.       , 0.       , ..., 1.1706175, 1.1706175,
#          1.1706175])},
#  {'time': array([0.0000e+00, 1.0000e-01, 2.0000e-01, ..., 1.1997e+03, 1.1998e+03,
#          1.1999e+03]),
#   'pop_rate_a': array([0.        , 0.        , 0.        , ..., 5.26777875, 5.26777875,
#          5.26777875]),
#   'pop_rate_b': array([0.        , 0.        , 0.        , ..., 0.58530875, 0.58530875,
#          0.58530875])},
#  {'time': array([0.0000e+00, 1.0000e-01, 2.0000e-01, ..., 1.1997e+03, 1.1998e+03,
#          1.1999e+03]),
#   'pop_rate_a': array([0.     , 0.     , 0.     , ..., 4.68247, 4.68247, 4.68247]),
#   'pop_rate_b': array([0.58530875, 0.58530875, 0.58530875, ..., 1.75592625, 1.75592625,
#          1.75592625])},
#  {'time': array([0.0000e+00, 1.0000e-01, 2.0000e-01, ..., 1.1997e+03, 1.1998e+03,
#          1.1999e+03]),
#   'pop_rate_a': array([0.     , 0.     , 0.     , ..., 4.68247, 4.68247, 4.68247]),
#   'pop_rate_b': array([0.       , 0.       , 0.       , ..., 1.1706175, 1.1706175,
#          1.1706175])},
#  {'time': array([0.0000e+00, 1.0000e-01, 2.0000e-01, ..., 1.1997e+03, 1.1998e+03,
#          1.1999e+03]),
#   'pop_rate_a': array([0.        , 0.        , 0.        , ..., 2.92654375, 2.92654375,
#          2.92654375]),
#   'pop_rate_b': array([0.      , 0.      , 0.      , ..., 2.341235, 2.341235, 2.341235])},
#  {'time': array([0.0000e+00, 1.0000e-01, 2.0000e-01, ..., 1.1997e+03, 1.1998e+03,
#          1.1999e+03]),
#   'pop_rate_a': array([1.75592625, 1.75592625, 1.75592625, ..., 0.58530875, 0.58530875,
#          0.58530875]),
#   'pop_rate_b': array([1.75592625, 1.75592625, 1.75592625, ..., 0.58530875, 0.58530875,
#          0.58530875])}]

# %%
def get_rt_session(data):

    def get_decision_time(pop_rate, threshold=25):
        rate_A = pop_rate['pop_rate_a']
        rate_B = pop_rate['pop_rate_b']
        
        above_thre_A = (pop_rate['pop_rate_a'] > threshold)
        idx_over_threshold_A = numpy.where(above_thre_A==True)


        above_thre_B = (pop_rate['pop_rate_b'] > threshold)
        idx_over_threshold_B = numpy.where(above_thre_B==True)

        # monitor each firing rate at every moment 
        decision_time_A = 0

        decision_time_B = 0

        for i in range(len(above_thre_A)):

            # find the time when the divergen starts happening

            above_thre_A = (rate_A > threshold)
            idx_over_threshold_A = numpy.where(above_thre_A==True)


            above_thre_B = (rate_B > threshold)
            idx_over_threshold_B = numpy.where(above_thre_B==True)



        if len(idx_over_threshold_A[0]) > 0:
            decision_time_A = idx_over_threshold_A[0][0];
            
        else: 
            pass

        if len(idx_over_threshold_B[0]) > 0:
            decision_time_B = idx_over_threshold_B[0][0];

        else: 
            pass
    

        #print(decision_time_A, decision_time_B)
        return decision_time_A, decision_time_B


    decision_times = []
    rt = []

    for i in range(len(data)):
        
        decision_time = get_decision_time(data[i])
        
        decision_times.append(decision_time)
        rt.append(max(decision_time))
        
        
    rt_in_realtime = numpy.array(rt) - 1000
    rt_in_realtime = rt_in_realtime/10
    

    return rt_in_realtime.mean()

# %%
rt_times = get_rt_session(data[keysList[60]])

# %%
rt_times
# Out:
# 131.95999999999998

# %%
rt_times_8_by_8 = {}

# %%
for i in range(len(keysList)):
    
    rt_times_8_by_8[keysList[i]] =  get_rt_session(data[keysList[i]])

# %%
rt_times_8_by_8
# Out:
# {(1.5, -70.0): 342.41999999999996,
#  (1.5, -71.5): 243.98000000000002,
#  (1.5, -73.0): -40.3,
#  (1.5, -74.5): -100.0,
f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Untitled-1.ipynb 셀 20 in <cell line: 4>()
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X56sdW50aXRsZWQ%3D?line=1'>2</a> time = curDT.strftime("%m%d_%H_%M")
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X56sdW50aXRsZWQ%3D?line=3'>4</a> with open('64_reaction_times' + time + '.pkl', 'wb') as f:
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X56sdW50aXRsZWQ%3D?line=4'>5</a>     pickle.dump(pop_rate_list, f)
#
# NameError: name 'pop_rate_list' is not defined

# %%
data[keysList[0]]
# Out:
# [{'time': array([0.0000e+00, 1.0000e-01, 2.0000e-01, ..., 1.1997e+03, 1.1998e+03,
#          1.1999e+03]),
#   'pop_rate_a': array([0.       , 0.       , 0.       , ..., 3.5118525, 3.5118525,
#          3.5118525]),
#   'pop_rate_b': array([0.      , 0.      , 0.      , ..., 2.341235, 2.341235, 2.341235])},
#  {'time': array([0.0000e+00, 1.0000e-01, 2.0000e-01, ..., 1.1997e+03, 1.1998e+03,
#          1.1999e+03]),
#   'pop_rate_a': array([0.        , 0.        , 0.        , ..., 1.75592625, 1.1706175 ,
#          1.1706175 ]),
#   'pop_rate_b': array([0.        , 0.        , 0.        , ..., 1.75592625, 1.75592625,
#          1.75592625])},
#  {'time': array([0.0000e+00, 1.0000e-01, 2.0000e-01, ..., 1.1997e+03, 1.1998e+03,
#          1.1999e+03]),
#   'pop_rate_a': array([0.      , 0.      , 0.      , ..., 2.341235, 2.341235, 2.341235]),
#   'pop_rate_b': array([0.58530875, 0.58530875, 1.1706175 , ..., 2.341235  , 2.341235  ,
#          2.341235  ])},
#  {'time': array([0.0000e+00, 1.0000e-01, 2.0000e-01, ..., 1.1997e+03, 1.1998e+03,
#          1.1999e+03]),
#   'pop_rate_a': array([1.1706175, 1.1706175, 1.1706175, ..., 2.341235 , 2.341235 ,
#          2.341235 ]),
#   'pop_rate_b': array([0.58530875, 0.58530875, 0.58530875, ..., 2.92654375, 2.341235  ,
#          2.341235  ])},
#  {'time': array([0.0000e+00, 1.0000e-01, 2.0000e-01, ..., 1.1997e+03, 1.1998e+03,
#          1.1999e+03]),
#   'pop_rate_a': array([0.      , 0.      , 0.      , ..., 2.341235, 2.341235, 2.341235]),
#   'pop_rate_b': array([0.       , 0.       , 0.       , ..., 1.1706175, 1.1706175,
#          1.1706175])},
#  {'time': array([0.0000e+00, 1.0000e-01, 2.0000e-01, ..., 1.1997e+03, 1.1998e+03,
#          1.1999e+03]),
#   'pop_rate_a': array([0.        , 0.        , 0.        , ..., 5.26777875, 5.26777875,
#          5.26777875]),
#   'pop_rate_b': array([0.        , 0.        , 0.        , ..., 0.58530875, 0.58530875,
#          0.58530875])},
#  {'time': array([0.0000e+00, 1.0000e-01, 2.0000e-01, ..., 1.1997e+03, 1.1998e+03,
#          1.1999e+03]),
#   'pop_rate_a': array([0.     , 0.     , 0.     , ..., 4.68247, 4.68247, 4.68247]),
#   'pop_rate_b': array([0.58530875, 0.58530875, 0.58530875, ..., 1.75592625, 1.75592625,
#          1.75592625])},
#  {'time': array([0.0000e+00, 1.0000e-01, 2.0000e-01, ..., 1.1997e+03, 1.1998e+03,
#          1.1999e+03]),
#   'pop_rate_a': array([0.     , 0.     , 0.     , ..., 4.68247, 4.68247, 4.68247]),
#   'pop_rate_b': array([0.       , 0.       , 0.       , ..., 1.1706175, 1.1706175,
#          1.1706175])},
#  {'time': array([0.0000e+00, 1.0000e-01, 2.0000e-01, ..., 1.1997e+03, 1.1998e+03,
#          1.1999e+03]),
#   'pop_rate_a': array([0.        , 0.        , 0.        , ..., 2.92654375, 2.92654375,
#          2.92654375]),
#   'pop_rate_b': array([0.      , 0.      , 0.      , ..., 2.341235, 2.341235, 2.341235])},
#  {'time': array([0.0000e+00, 1.0000e-01, 2.0000e-01, ..., 1.1997e+03, 1.1998e+03,
#          1.1999e+03]),
#   'pop_rate_a': array([1.75592625, 1.75592625, 1.75592625, ..., 0.58530875, 0.58530875,
#          0.58530875]),
#   'pop_rate_b': array([1.75592625, 1.75592625, 1.75592625, ..., 0.58530875, 0.58530875,
#          0.58530875])}]

# %%
keysList[0]
# Out:
# (1.5, -70.0)

# %%
rt_times
# Out:
# 342.41999999999996

# %%
mean_rt_time = numpy.array(rt_times)

# %%
mean_rt_time
# Out:
# array(342.42)

# %%
data(keysList[0])
# Out:
# (1.5, -70.0)

# %%
numpy.mean(rt_times)
# Out:
# 342.41999999999996

# %%
rt_in_realtime = numpy.array(rt_times) - 1000
rt_in_realtime = rt_in_realtime/10

# %%
rt_in_realtime.mean()
# Out:
# 342.41999999999996
